# %% [markdown]
# # 🌿 Betel Leaf Disease Detection — Early Fusion ViT-Small
# **CSE 438 Group-4 | Fusion Method: Early Fusion (RGB + Edge Channel Concatenation)**
#
# ---
# ## Pipeline Overview
# | Step | Description |
# |------|-------------|
# | Step 1  | Install & Import Libraries |
# | Step 2  | Dataset Download & Directory Setup |
# | Step 3  | Data Exploration & Class Distribution |
# | Step 4  | Data Augmentation & Early Fusion Transform |
# | Step 5  | Dataset & DataLoader Creation |
# | Step 6  | Early Fusion Model Building (ViT-Small/16) |
# | Step 7  | Training Loop with Validation |
# | Step 8  | Training Curves Visualization |
# | Step 9  | Final Test Evaluation & Metrics |
# | Step 10 | Confusion Matrix & Per-Class Report |
#
# > **Backbone:** ViT-Small/16 (Vision Transformer, pretrained ImageNet-21k via `timm`)
# > **Fusion Type:** Early Fusion — RGB (3ch) + Sobel Edge Map (1ch) → 4-channel input
# > **Key difference:** ViT has no conv1 — instead, the **patch embedding projection** (`patch_embed.proj`) is modified from 3→4 input channels. This is the correct early-fusion entry point for Transformers.

# %% [markdown]
# ---
# ## ✅ Step 1 — Install & Import Libraries

# %%
import subprocess, sys
packages = ["timm", "scikit-learn", "matplotlib", "seaborn", "Pillow", "torchvision"]
for pkg in packages:
    result = subprocess.run([sys.executable, "-m", "pip", "install", pkg, "-q"],
                            capture_output=True, text=True)
    print(f"[OK] {pkg}" if result.returncode == 0 else f"[FAIL] {pkg}: {result.stderr[:80]}")
print("\n✅ All packages ready!")

import os, random, time, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from PIL import Image, ImageFilter
from collections import Counter

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
import torchvision.transforms as transforms
import torchvision.models as tv_models
import timm

from sklearn.metrics import (classification_report, confusion_matrix,
                              f1_score, precision_score, recall_score)
warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(SEED)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"\n🖥️  Device  : {DEVICE}")
if DEVICE.type == "cuda":
    print(f"   GPU     : {torch.cuda.get_device_name(0)}")
    print(f"   VRAM    : {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
print(f"   PyTorch : {torch.__version__}")
print(f"   timm    : {timm.__version__}")
# Out:
# [OK] timm
# [OK] scikit-learn
# [OK] matplotlib
# [OK] seaborn
# [OK] Pillow
# [OK] torchvision
#
# ✅ All packages ready!
#
# 🖥️  Device  : cuda
#    GPU     : Tesla T4
#    VRAM    : 15.6 GB
#    PyTorch : 2.10.0+cu128
#    timm    : 1.0.25

# %% [markdown]
# ---
# ## ✅ Step 2 — Dataset Download & Directory Setup
#
# Dataset source: https://data.mendeley.com/datasets/vpzkntzjty/1
# > On Kaggle: **Add Data → Datasets** → search `"Comprehensive Betel Leaf Disease"` → add it.

# %%
CLASS_NAMES  = ["Healthy_Leaf", "Leaf_Rot", "Leaf_Spot"]
DATASET_ROOT = None

for root in ["/kaggle/input", "./data", "."]:
    for dirpath, dirnames, _ in os.walk(root):
        if "Original_Dataset" in dirnames:
            DATASET_ROOT = Path(dirpath) / "Original_Dataset"
            print(f"✅ Found Original_Dataset at: {DATASET_ROOT}")
            break
    if DATASET_ROOT: break

if DATASET_ROOT is None:
    print("⚠️  Original_Dataset not found — creating synthetic demo data...")
    DATASET_ROOT = Path("/kaggle/working/demo_dataset")
    for split in ["train", "val", "test"]:
        for cls in CLASS_NAMES:
            (DATASET_ROOT / split / cls).mkdir(parents=True, exist_ok=True)
            for i in range(30 if split == "train" else 10):
                img = Image.fromarray(np.random.randint(50, 200, (224, 224, 3), dtype=np.uint8))
                img.save(DATASET_ROOT / split / cls / f"img_{i:04d}.jpg")
    print(f"✅ Demo dataset created at: {DATASET_ROOT}")
    DEMO_MODE = True
else:
    DEMO_MODE = False

if not DEMO_MODE:
    from sklearn.model_selection import train_test_split
    import shutil
    SPLIT_ROOT = Path("/kaggle/working/split_dataset")
    if not SPLIT_ROOT.exists():
        print("\n📁 Creating train/val/test splits (70 / 15 / 15)...")
        for cls in CLASS_NAMES:
            all_imgs = (sorted((DATASET_ROOT / cls).glob("*.jpg")) +
                        sorted((DATASET_ROOT / cls).glob("*.png")) +
                        sorted((DATASET_ROOT / cls).glob("*.jpeg")))
            tr, temp = train_test_split(all_imgs, test_size=0.30, random_state=SEED)
            vl, te   = train_test_split(temp,     test_size=0.50, random_state=SEED)
            for split_name, imgs in [("train", tr), ("val", vl), ("test", te)]:
                dest = SPLIT_ROOT / split_name / cls
                dest.mkdir(parents=True, exist_ok=True)
                for src in imgs: shutil.copy(src, dest / src.name)
            print(f"   {cls:<15} → train:{len(tr):4d}  val:{len(vl):4d}  test:{len(te):4d}")
        print("✅ Splits ready!")
    DATASET_ROOT = SPLIT_ROOT

print("\n📊 Dataset Summary:")
for split in ["train", "val", "test"]:
    total = sum(len(list((DATASET_ROOT / split / c).glob("*.*")))
                for c in CLASS_NAMES if (DATASET_ROOT / split / c).exists())
    print(f"   {split:>5}: {total:5d} images")

# ViT-Small/16 needs 224x224 (patch_size=16, grid=14×14)
IMG_SIZE    = 224
NUM_CLASSES = len(CLASS_NAMES)
BATCH_SIZE  = 32   # ViT uses more memory per image
NUM_EPOCHS  = 20
LR          = 1e-4
NUM_WORKERS = 2

print(f"\n⚙️  Config: IMG={IMG_SIZE}  Classes={NUM_CLASSES}  "
      f"Batch={BATCH_SIZE}  Epochs={NUM_EPOCHS}  LR={LR}")
# Out:
# ✅ Found Original_Dataset at: /kaggle/input/datasets/mikeafridi/cse-438-group-4/Comprehensive Betel Leaf Disease Dataset for Advanced Pathology Research/Betel Leaf Dataset/Betel Leaf Dataset/Betel Leaf Dataset/Original_Dataset
#
# 📁 Creating train/val/test splits (70 / 15 / 15)...
#    Healthy_Leaf    → train: 756  val: 162  test: 162
#    Leaf_Rot        → train: 188  val:  40  test:  41
#    Leaf_Spot       → train: 481  val: 103  test: 104
# ✅ Splits ready!
#
# 📊 Dataset Summary:
#    train:  1425 images
#      val:   305 images
#     test:   307 images
#
# ⚙️  Config: IMG=224  Classes=3  Batch=32  Epochs=20  LR=0.0001

# %% [markdown]
# ---
# ## ✅ Step 3 — Data Exploration & Class Distribution

# %%
records = []
for split in ["train", "val", "test"]:
    for cls in CLASS_NAMES:
        folder = DATASET_ROOT / split / cls
        if folder.exists():
            imgs = (list(folder.glob("*.jpg")) + list(folder.glob("*.png")) +
                    list(folder.glob("*.jpeg")))
            records.append({"Split": split, "Class": cls, "Count": len(imgs)})

df_dist = pd.DataFrame(records)
print("📊 Class Distribution Table")
print(df_dist.pivot(index="Class", columns="Split", values="Count").fillna(0).astype(int))

colors = ["#4CAF50", "#F44336", "#FF9800"]
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle("Betel Leaf Dataset — Distribution (ViT-Small Notebook)",
             fontsize=13, fontweight="bold")

ax = axes[0]
x = np.arange(len(CLASS_NAMES)); w = 0.25
for i, (split, col) in enumerate(zip(["train", "val", "test"],
                                      ["#3498db", "#e74c3c", "#2ecc71"])):
    vals = [df_dist[(df_dist.Split == split) & (df_dist.Class == c)]["Count"].sum()
            for c in CLASS_NAMES]
    ax.bar(x + i * w, vals, w, label=split, color=col, alpha=0.85)
ax.set_xticks(x + w); ax.set_xticklabels(CLASS_NAMES, rotation=10)
ax.set_title("Count per Class per Split"); ax.set_ylabel("Count")
ax.legend(); ax.grid(axis="y", alpha=0.3)

ax2 = axes[1]
train_counts = [df_dist[(df_dist.Split == "train") & (df_dist.Class == c)]["Count"].sum()
                for c in CLASS_NAMES]
ax2.pie(train_counts, labels=CLASS_NAMES, colors=colors, autopct="%1.1f%%",
        startangle=140, explode=[0.05] * 3)
ax2.set_title("Train Proportions")
plt.tight_layout()
plt.savefig("/kaggle/working/vit_step3_distribution.png", dpi=120, bbox_inches="tight")
plt.show()

fig2, axes2 = plt.subplots(1, 3, figsize=(12, 4))
fig2.suptitle("Sample Images — Each Class", fontsize=13, fontweight="bold")
for ax, cls, color in zip(axes2, CLASS_NAMES, colors):
    folder = DATASET_ROOT / "train" / cls
    sample = list(folder.glob("*.*"))[0]
    ax.imshow(Image.open(sample).resize((224, 224)))
    ax.set_title(cls, color=color, fontweight="bold"); ax.axis("off")
plt.tight_layout()
plt.savefig("/kaggle/working/vit_step3_samples.png", dpi=120, bbox_inches="tight")
plt.show()
print("✅ Step 3 complete.")
# Out:
# 📊 Class Distribution Table
# Split         test  train  val
# Class
# Healthy_Leaf   162    756  162
# Leaf_Rot        41    188   40
# Leaf_Spot      104    481  103
# ✅ Step 3 complete.

# %% [markdown]
# ---
# ## ✅ Step 4 — Data Augmentation & Early Fusion Transform
#
# **Early Fusion Strategy:**
# - Channel 0-2 → Normalized RGB
# - Channel 3   → Sobel Edge Map
# - Concatenate → **4-channel tensor [B, 4, 224, 224]**
#
# For ViT, the early fusion entry point is the **patch embedding conv** (`patch_embed.proj`),
# not a traditional `conv1`. This conv projects patches → token embeddings.
# We modify it from `in_channels=3` → `in_channels=4`.

# %%
MEAN_RGB  = [0.485, 0.456, 0.406]
STD_RGB   = [0.229, 0.224, 0.225]
MEAN_EDGE = [0.5]
STD_EDGE  = [0.5]

class EarlyFusionTransform:
    """
    Early Fusion: RGB (3ch) + Sobel Edge (1ch) → 4-channel tensor.
    Augmentation applied only during training.
    """
    def __init__(self, is_train=True):
        self.is_train  = is_train
        self.resize    = transforms.Resize((IMG_SIZE, IMG_SIZE))
        self.to_tensor = transforms.ToTensor()
        self.aug = transforms.Compose([
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomVerticalFlip(p=0.2),
            transforms.RandomRotation(degrees=15),
            transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.2, hue=0.05),
            transforms.RandomGrayscale(p=0.05),
        ])
        self.norm_rgb  = transforms.Normalize(MEAN_RGB, STD_RGB)
        self.norm_edge = transforms.Normalize(MEAN_EDGE, STD_EDGE)

    def _edge_channel(self, pil_img):
        edge_t = self.to_tensor(pil_img.convert("L").filter(ImageFilter.FIND_EDGES))
        return self.norm_edge(edge_t)

    def __call__(self, pil_img):
        img    = self.resize(pil_img)
        if self.is_train: img = self.aug(img)
        rgb_t  = self.norm_rgb(self.to_tensor(img))
        edge_t = self._edge_channel(img)
        return torch.cat([rgb_t, edge_t], dim=0)   # [4, H, W]


train_transform = EarlyFusionTransform(is_train=True)
val_transform   = EarlyFusionTransform(is_train=False)

sample_path = list((DATASET_ROOT / "train" / CLASS_NAMES[0]).glob("*.*"))[0]
sample_pil  = Image.open(sample_path).convert("RGB")
fused       = train_transform(sample_pil)

fig, axes = plt.subplots(1, 5, figsize=(18, 4))
fig.suptitle("Early Fusion — 4-Channel Input (ViT-Small/16)",
             fontsize=13, fontweight="bold")
axes[0].imshow(sample_pil.resize((224, 224)))
axes[0].set_title("Original"); axes[0].axis("off")
for i, (name, cmap) in enumerate(zip(
        ["R (ch0)", "G (ch1)", "B (ch2)", "Edge (ch3)"],
        ["Reds", "Greens", "Blues", "gray"])):
    axes[i + 1].imshow(fused[i].numpy(), cmap=cmap)
    axes[i + 1].set_title(name); axes[i + 1].axis("off")
plt.tight_layout()
plt.savefig("/kaggle/working/vit_step4_fusion_channels.png", dpi=120, bbox_inches="tight")
plt.show()
print(f"✅ Step 4 complete — Fused tensor shape: {fused.shape}")
print(f"   ViT will split this 224×224 tensor into 14×14 = 196 patches of size 16×16×4")
# Out:
# ✅ Step 4 complete — Fused tensor shape: torch.Size([4, 224, 224])
#    ViT will split this 224×224 tensor into 14×14 = 196 patches of size 16×16×4

# %% [markdown]
# ---
# ## ✅ Step 5 — Dataset & DataLoader Creation

# %%
class BetelLeafFusionDataset(Dataset):
    def __init__(self, root_dir, class_names, transform=None):
        self.class_names  = class_names
        self.class_to_idx = {c: i for i, c in enumerate(class_names)}
        self.transform    = transform
        self.samples      = []
        for cls in class_names:
            folder = Path(root_dir) / cls
            if not folder.exists(): continue
            for ext in ["*.jpg", "*.jpeg", "*.png", "*.JPG", "*.PNG"]:
                for p in sorted(folder.glob(ext)):
                    self.samples.append((str(p), self.class_to_idx[cls]))

    def __len__(self): return len(self.samples)

    def __getitem__(self, idx):
        path, label = self.samples[idx]
        try:    img = Image.open(path).convert("RGB")
        except: img = Image.fromarray(np.zeros((224, 224, 3), dtype=np.uint8))
        if self.transform: img = self.transform(img)
        return img, label


train_ds = BetelLeafFusionDataset(DATASET_ROOT / "train", CLASS_NAMES, train_transform)
val_ds   = BetelLeafFusionDataset(DATASET_ROOT / "val",   CLASS_NAMES, val_transform)
test_ds  = BetelLeafFusionDataset(DATASET_ROOT / "test",  CLASS_NAMES, val_transform)
print(f"📦 Sizes → Train: {len(train_ds)}  Val: {len(val_ds)}  Test: {len(test_ds)}")

labels_train = [s[1] for s in train_ds.samples]
class_counts = Counter(labels_train)
weights      = [1.0 / class_counts[l] for l in labels_train]
sampler      = WeightedRandomSampler(weights, num_samples=len(weights), replacement=True)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, sampler=sampler,
                          num_workers=NUM_WORKERS, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False,
                          num_workers=NUM_WORKERS, pin_memory=True)

batch_imgs, batch_labels = next(iter(train_loader))
print(f"\n🔍 Batch check:")
print(f"   Image tensor : {batch_imgs.shape}  (B × 4 × H × W)")
print(f"   Labels       : {batch_labels[:8].tolist()}")
print(f"   Value range  : [{batch_imgs.min():.3f}, {batch_imgs.max():.3f}]")
print("\n✅ Step 5 complete — DataLoaders ready!")
# Out:
# 📦 Sizes → Train: 1425  Val: 305  Test: 307
#
# 🔍 Batch check:
#    Image tensor : torch.Size([32, 4, 224, 224])  (B × 4 × H × W)
#    Labels       : [1, 1, 1, 0, 1, 1, 0, 1]
#    Value range  : [-2.118, 2.640]
#
# ✅ Step 5 complete — DataLoaders ready!

# %% [markdown]
# ---
# ## ✅ Step 6 — Early Fusion Model Building (ViT-Small/16)
#
# **Architecture details:**
# - Backbone: `vit_small_patch16_224` from `timm` (pretrained ImageNet-21k → 1k)
# - Early fusion entry: **`model.patch_embed.proj`** — the conv layer that converts image patches to token embeddings
#   - Default: `Conv2d(3, 384, kernel_size=16, stride=16)` (one 16×16 patch → one 384-dim token)
#   - Modified: `Conv2d(4, 384, kernel_size=16, stride=16)` — accepts 4-channel fused input
# - `num_heads=6`, `depth=12`, `embed_dim=384` — standard ViT-Small config
# - Head replaced with `Linear(384 → num_classes)`

# %%
class EarlyFusionViTSmall(nn.Module):
    """
    Early Fusion ViT-Small/16:
    - patch_embed.proj: 3ch → 4ch (RGB + Edge)
    - Pretrained RGB patch embedding weights preserved
    - 4th channel weights initialised as mean of RGB patch embed weights
    - Head: Linear(384 → num_classes)

    NOTE: In ViT, 'early fusion' means modifying the PATCH EMBEDDING conv,
    which is functionally equivalent to changing conv1 in CNNs.
    The image is split into 14×14 = 196 patches of size [4, 16, 16],
    each projected to a 384-dim embedding token.
    """
    def __init__(self, num_classes=3, dropout=0.1):
        super().__init__()
        # Load pretrained ViT-Small/16 via timm
        self.backbone = timm.create_model(
            "vit_small_patch16_224",
            pretrained=True,
            num_classes=num_classes
        )

        # ── Modify patch embedding (PDF Step 3.3 equivalent for ViT) ───────
        old_proj = self.backbone.patch_embed.proj
        # Original: Conv2d(3, 384, kernel_size=(16,16), stride=(16,16))
        new_proj = nn.Conv2d(
            in_channels=4,
            out_channels=old_proj.out_channels,   # 384
            kernel_size=old_proj.kernel_size,      # (16, 16)
            stride=old_proj.stride,                # (16, 16)
            padding=old_proj.padding if hasattr(old_proj, 'padding') else 0,
            bias=(old_proj.bias is not None)
        )
        with torch.no_grad():
            new_proj.weight[:, :3, :, :] = old_proj.weight
            new_proj.weight[:, 3:4, :, :] = old_proj.weight.mean(dim=1, keepdim=True)
            if old_proj.bias is not None:
                new_proj.bias.copy_(old_proj.bias)
        self.backbone.patch_embed.proj = new_proj

        # ── Dropout before head ────────────────────────────────────────────
        embed_dim   = self.backbone.head.in_features  # 384
        self.backbone.head = nn.Sequential(
            nn.Dropout(p=dropout),
            nn.Linear(embed_dim, num_classes)
        )

    def forward(self, x):   # x: [B, 4, 224, 224]
        return self.backbone(x)


model = EarlyFusionViTSmall(num_classes=NUM_CLASSES, dropout=0.1).to(DEVICE)

total_p     = sum(p.numel() for p in model.parameters())
trainable_p = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"🏗️  Model    : Early Fusion ViT-Small/16")
print(f"   Input    : 4 channels (RGB + Edge map)")
print(f"   Patches  : 14×14 = 196 tokens per image")
print(f"   Embed dim: 384  |  Heads: 6  |  Depth: 12")
print(f"   Output   : {NUM_CLASSES} classes")
print(f"   Total params    : {total_p:,}")
print(f"   Trainable params: {trainable_p:,}")
print(f"   Patch embed proj: {model.backbone.patch_embed.proj}")
print(f"   Head            : {model.backbone.head}")

model.eval()
with torch.no_grad():
    dummy = torch.randn(2, 4, IMG_SIZE, IMG_SIZE).to(DEVICE)
    out   = model(dummy)
print(f"\n✅ Forward pass OK — Output shape: {out.shape}")
print(f"   Each 224×224 image → 196 patch tokens of dim 384 → CLS token → head → {NUM_CLASSES} logits")

criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
# ViT benefits from layer-wise LR decay — simplified: lower LR for backbone, higher for head
backbone_params = [p for n, p in model.named_parameters() if "head" not in n]
head_params     = [p for n, p in model.named_parameters() if "head" in n]
optimizer = optim.AdamW([
    {"params": backbone_params, "lr": LR * 0.1},   # lower LR for pretrained transformer
    {"params": head_params,     "lr": LR}           # higher LR for new head
], weight_decay=0.05)  # ViT benefits from higher weight decay
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=NUM_EPOCHS, eta_min=1e-7)

print(f"\n⚙️  Loss: CrossEntropyLoss(label_smoothing=0.1)")
print(f"   Optimizer: AdamW with layer-wise LR:")
print(f"     backbone LR = {LR*0.1:.1e}  (lower for pretrained transformer)")
print(f"     head LR     = {LR:.1e}      (higher for new classification head)")
print(f"   Weight decay : 0.05 (standard for ViT)")
print(f"   Scheduler    : CosineAnnealing(T_max={NUM_EPOCHS})")
print("\n✅ Step 6 complete — ViT-Small model ready!")
# Out:
# model.safetensors:   0%|          | 0.00/88.2M [00:00<?, ?B/s]
# 🏗️  Model    : Early Fusion ViT-Small/16
#    Input    : 4 channels (RGB + Edge map)
#    Patches  : 14×14 = 196 tokens per image
#    Embed dim: 384  |  Heads: 6  |  Depth: 12
#    Output   : 3 classes
#    Total params    : 21,765,123
#    Trainable params: 21,765,123
#    Patch embed proj: Conv2d(4, 384, kernel_size=(16, 16), stride=(16, 16))
#    Head            : Sequential(
#   (0): Dropout(p=0.1, inplace=False)
#   (1): Linear(in_features=384, out_features=3, bias=True)
# )
#
# ✅ Forward pass OK — Output shape: torch.Size([2, 3])
#    Each 224×224 image → 196 patch tokens of dim 384 → CLS token → head → 3 logits
#
# ⚙️  Loss: CrossEntropyLoss(label_smoothing=0.1)
#    Optimizer: AdamW with layer-wise LR:
#      backbone LR = 1.0e-05  (lower for pretrained transformer)
#      head LR     = 1.0e-04      (higher for new classification head)
#    Weight decay : 0.05 (standard for ViT)
#    Scheduler    : CosineAnnealing(T_max=20)
#
# ✅ Step 6 complete — ViT-Small model ready!

# %% [markdown]
# ---
# ## ✅ Step 7 — Training Loop with Validation
#
# PDF **Phase 4**: train → validate → save best checkpoint (lowest val loss).

# %%
CKPT_PATH = "/kaggle/working/best_vit_early_fusion.pth"

def train_one_epoch(model, loader, criterion, optimizer, device):
    model.train()
    total_loss = correct = total = 0
    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(imgs)
        loss    = criterion(outputs, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        total_loss += loss.item() * imgs.size(0)
        correct    += (outputs.argmax(1) == labels).sum().item()
        total      += imgs.size(0)
    return total_loss / total, correct / total


@torch.no_grad()
def evaluate(model, loader, criterion, device):
    model.eval()
    total_loss = correct = total = 0
    all_preds, all_labels = [], []
    for imgs, labels in loader:
        imgs, labels = imgs.to(device), labels.to(device)
        outputs     = model(imgs)
        total_loss += criterion(outputs, labels).item() * imgs.size(0)
        preds       = outputs.argmax(1)
        correct    += (preds == labels).sum().item()
        total      += imgs.size(0)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
    return (total_loss / total, correct / total,
            np.array(all_preds), np.array(all_labels))


history = {"train_loss": [], "val_loss": [], "train_acc": [],
           "val_acc": [], "val_f1": [], "lr": []}
best_val_loss = float("inf")
best_val_acc  = 0.0
patience = 7; no_improve = 0

print(f"🚀 Training ViT-Small/16 for {NUM_EPOCHS} epochs on {DEVICE}")
print(f"   (ViT is slower per epoch than CNNs — ~2-3x per epoch on same GPU)")
print(f"{'Epoch':>6} {'Train Loss':>11} {'Train Acc':>10} {'Val Loss':>10} "
      f"{'Val Acc':>9} {'Val F1':>8} {'LR (head)':>12}")
print("-" * 75)

start_total = time.time()
for epoch in range(1, NUM_EPOCHS + 1):
    t0 = time.time()
    train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, DEVICE)
    val_loss, val_acc, val_preds, val_true = evaluate(model, val_loader, criterion, DEVICE)
    val_f1 = f1_score(val_true, val_preds, average="weighted", zero_division=0)
    # Report head LR (param group 1)
    cur_lr = optimizer.param_groups[1]["lr"]
    scheduler.step()

    for k, v in zip(["train_loss", "val_loss", "train_acc", "val_acc", "val_f1", "lr"],
                    [train_loss, val_loss, train_acc, val_acc, val_f1, cur_lr]):
        history[k].append(v)

    marker = ""
    if val_loss < best_val_loss:
        best_val_loss = val_loss; best_val_acc = val_acc
        torch.save({"epoch": epoch, "model_state_dict": model.state_dict(),
                    "optimizer_state_dict": optimizer.state_dict(),
                    "val_loss": val_loss, "val_acc": val_acc, "val_f1": val_f1}, CKPT_PATH)
        no_improve = 0; marker = " ✓ SAVED"
    else:
        no_improve += 1

    print(f"{epoch:>6} {train_loss:>11.4f} {train_acc*100:>9.2f}% "
          f"{val_loss:>10.4f} {val_acc*100:>8.2f}% "
          f"{val_f1:>8.4f} {cur_lr:>12.2e}  ({time.time()-t0:.1f}s){marker}")
    if no_improve >= patience:
        print(f"\n⏹️  Early stopping at epoch {epoch}"); break

print(f"\n✅ Training done in {(time.time()-start_total)/60:.1f} min")
print(f"   Best val loss: {best_val_loss:.4f}  |  Best val acc: {best_val_acc*100:.2f}%")
# Out:
# 🚀 Training ViT-Small/16 for 20 epochs on cuda
#    (ViT is slower per epoch than CNNs — ~2-3x per epoch on same GPU)
#  Epoch  Train Loss  Train Acc   Val Loss   Val Acc   Val F1    LR (head)
# ---------------------------------------------------------------------------
#      1      0.9789     61.26%     0.6693    80.66%   0.8169     1.00e-04  (20.2s) ✓ SAVED
#      2      0.5919     85.12%     0.6027    83.93%   0.8472     9.94e-05  (19.4s) ✓ SAVED
#      3      0.5363     88.00%     0.5012    88.85%   0.8907     9.76e-05  (19.6s) ✓ SAVED
#      4      0.4998     90.04%     0.4812    90.82%   0.9086     9.46e-05  (19.9s) ✓ SAVED
#      5      0.4632     91.58%     0.5174    90.49%   0.9063     9.05e-05  (19.0s)
#      6      0.4218     95.09%     0.4578    92.79%   0.9280     8.54e-05  (20.2s) ✓ SAVED
#      7      0.4383     93.54%     0.4566    93.44%   0.9338     7.94e-05  (20.4s) ✓ SAVED
#      8      0.4225     93.82%     0.5076    88.85%   0.8898     7.27e-05  (19.8s)
#      9      0.4131     94.81%     0.4449    93.44%   0.9345     6.55e-05  (19.9s) ✓ SAVED
#     10      0.4041     95.44%     0.4330    93.77%   0.9376     5.79e-05  (20.5s) ✓ SAVED
#     11      0.3939     95.30%     0.4446    93.77%   0.9378     5.01e-05  (19.4s)
#     12      0.3848     95.86%     0.4328    93.11%   0.9309     4.22e-05  (20.3s) ✓ SAVED
#     13      0.3808     96.35%     0.4383    94.43%   0.9443     3.46e-05  (19.6s)
#     14      0.3718     96.77%     0.4324    94.43%   0.9443     2.74e-05  (20.3s) ✓ SAVED
#     15      0.3699     96.98%     0.4290    94.10%   0.9410     2.07e-05  (20.5s) ✓ SAVED
#     16      0.3760     96.49%     0.4293    94.43%   0.9441     1.47e-05  (19.9s)
#     17      0.3644     98.04%     0.4305    94.43%   0.9442     9.64e-06  (19.7s)
#     18      0.3664     96.98%     0.4288    94.43%   0.9442     5.54e-06  (20.6s) ✓ SAVED
#     19      0.3779     96.00%     0.4311    94.10%   0.9411     2.54e-06  (19.7s)
#     20      0.3674     97.12%     0.4303    94.10%   0.9411     7.15e-07  (20.1s)
#
# ✅ Training done in 6.6 min
#    Best val loss: 0.4288  |  Best val acc: 94.43%

# %% [markdown]
# ---
# ## ✅ Step 8 — Training Curves Visualization

# %%
epochs_ran = list(range(1, len(history["train_loss"]) + 1))
fig, axes  = plt.subplots(1, 3, figsize=(18, 5))
fig.suptitle("Early Fusion ViT-Small/16 — Training Curves",
             fontsize=14, fontweight="bold")

ax = axes[0]
ax.plot(epochs_ran, history["train_loss"], "b-o", ms=4, label="Train Loss")
ax.plot(epochs_ran, history["val_loss"],   "r-s", ms=4, label="Val Loss")
best_ep = history["val_loss"].index(min(history["val_loss"])) + 1
ax.axvline(best_ep, color="green", linestyle="--", alpha=0.7, label=f"Best ep {best_ep}")
ax.set_title("Loss"); ax.set_xlabel("Epoch"); ax.set_ylabel("CrossEntropy")
ax.legend(); ax.grid(alpha=0.3)

ax2 = axes[1]
ax2.plot(epochs_ran, [v * 100 for v in history["train_acc"]], "b-o", ms=4, label="Train Acc")
ax2.plot(epochs_ran, [v * 100 for v in history["val_acc"]],   "r-s", ms=4, label="Val Acc")
ax2.axvline(best_ep, color="green", linestyle="--", alpha=0.7)
ax2.set_title("Accuracy"); ax2.set_xlabel("Epoch"); ax2.set_ylabel("Accuracy (%)")
ax2.set_ylim([0, 105]); ax2.legend(); ax2.grid(alpha=0.3)

ax3 = axes[2]
ax3.plot(epochs_ran, history["val_f1"], color="#8e44ad", marker="^", ms=4, label="Val F1")
ax3b = ax3.twinx()
ax3b.plot(epochs_ran, history["lr"], color="#e67e22", linestyle="--", label="Head LR")
ax3.set_title("Val F1 & Head LR"); ax3.set_xlabel("Epoch")
ax3.set_ylabel("Weighted F1", color="#8e44ad")
ax3b.set_ylabel("Learning Rate", color="#e67e22")
ax3.legend(loc="upper left"); ax3b.legend(loc="upper right")
ax3.grid(alpha=0.3)

plt.tight_layout()
plt.savefig("/kaggle/working/vit_step8_training_curves.png", dpi=120, bbox_inches="tight")
plt.show()
print(f"\n📈 Best epoch: {best_ep} | Best val acc: {max(history['val_acc'])*100:.2f}% | "
      f"Best val F1: {max(history['val_f1']):.4f}")
print("✅ Step 8 complete.")
# Out:
# 📈 Best epoch: 18 | Best val acc: 94.43% | Best val F1: 0.9443
# ✅ Step 8 complete.

# %% [markdown]
# ---
# ## ✅ Step 9 — Final Test Evaluation & Metrics
#
# PDF **Phase 6**: Run best model on test set once.

# %%
ckpt = torch.load(CKPT_PATH, map_location=DEVICE)
model.load_state_dict(ckpt["model_state_dict"])
print(f"✅ Loaded best checkpoint — epoch {ckpt['epoch']}  "
      f"val_loss={ckpt['val_loss']:.4f}  val_acc={ckpt['val_acc']*100:.2f}%")

print("\n🔬 Running inference on test set...")
test_loss, test_acc, test_preds, test_true = evaluate(model, test_loader, criterion, DEVICE)

acc_pct      = test_acc * 100
weighted_f1  = f1_score(test_true, test_preds, average="weighted", zero_division=0)
macro_f1     = f1_score(test_true, test_preds, average="macro",    zero_division=0)
per_class_f1 = f1_score(test_true, test_preds, average=None,       zero_division=0)

print("\n" + "=" * 50)
print("  FINAL TEST RESULTS — Early Fusion ViT-Small/16")
print("=" * 50)
print(f"  {'Accuracy':<24}{acc_pct:.2f}%")
print(f"  {'Weighted F1':<24}{weighted_f1:.4f}")
print(f"  {'Macro F1':<24}{macro_f1:.4f}")
print(f"  {'Test Loss':<24}{test_loss:.4f}")
print("-" * 50)
print("  Per-Class F1:")
for cls, f1 in zip(CLASS_NAMES, per_class_f1):
    print(f"    {cls:<20} {f1:.4f}  {'█' * int(f1 * 30)}")
print("=" * 50)

print("\n📋 Classification Report:")
print(classification_report(test_true, test_preds,
                             target_names=CLASS_NAMES, digits=4))

pd.DataFrame({
    "Metric": ["Accuracy", "Weighted F1", "Macro F1"] + [f"F1_{c}" for c in CLASS_NAMES],
    "Value":  [acc_pct/100, weighted_f1, macro_f1] + list(per_class_f1)
}).to_csv("/kaggle/working/vit_step9_test_results.csv", index=False)
print("✅ Step 9 complete — results saved.")
# Out:
# ✅ Loaded best checkpoint — epoch 18  val_loss=0.4288  val_acc=94.43%
#
# 🔬 Running inference on test set...
#
# ==================================================
#   FINAL TEST RESULTS — Early Fusion ViT-Small/16
# ==================================================
#   Accuracy                94.46%
#   Weighted F1             0.9447
#   Macro F1                0.9413
#   Test Loss               0.3938
# --------------------------------------------------
#   Per-Class F1:
#     Healthy_Leaf         0.9595  ████████████████████████████
#     Leaf_Rot             0.9412  ████████████████████████████
#     Leaf_Spot            0.9231  ███████████████████████████
# ==================================================
#
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
# Healthy_Leaf     0.9686    0.9506    0.9595       162
#     Leaf_Rot     0.9091    0.9756    0.9412        41
#    Leaf_Spot     0.9231    0.9231    0.9231       104
#
#     accuracy                         0.9446       307
#    macro avg     0.9336    0.9498    0.9413       307
# weighted avg     0.9452    0.9446    0.9447       307
#
# ✅ Step 9 complete — results saved.

# %% [markdown]
# ---
# ## ✅ Step 10 — Confusion Matrix & Per-Class Analysis

# %%
cm      = confusion_matrix(test_true, test_preds)
cm_norm = cm.astype("float") / cm.sum(axis=1, keepdims=True)

fig, axes = plt.subplots(1, 2, figsize=(16, 6))
fig.suptitle("Early Fusion ViT-Small/16 — Test Set Confusion Matrix",
             fontsize=14, fontweight="bold")
sns.heatmap(cm,      annot=True, fmt="d",   cmap="Blues",  ax=axes[0],
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
axes[0].set_title("Counts"); axes[0].set_xlabel("Predicted"); axes[0].set_ylabel("True")
sns.heatmap(cm_norm, annot=True, fmt=".2%", cmap="RdYlGn", ax=axes[1],
            xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES, vmin=0, vmax=1)
axes[1].set_title("Normalized"); axes[1].set_xlabel("Predicted"); axes[1].set_ylabel("True")
plt.tight_layout()
plt.savefig("/kaggle/working/vit_step10_confusion_matrix.png", dpi=120, bbox_inches="tight")
plt.show()

per_prec   = precision_score(test_true, test_preds, average=None, zero_division=0)
per_recall = recall_score(test_true,    test_preds, average=None, zero_division=0)

fig2, ax = plt.subplots(figsize=(10, 5))
x = np.arange(len(CLASS_NAMES)); w = 0.25
b1 = ax.bar(x - w, per_prec,     w, label="Precision", color="#3498db", alpha=0.85)
b2 = ax.bar(x,     per_recall,   w, label="Recall",    color="#2ecc71", alpha=0.85)
b3 = ax.bar(x + w, per_class_f1, w, label="F1 Score",  color="#e74c3c", alpha=0.85)
for bars in [b1, b2, b3]:
    for bar in bars:
        h = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, h + 0.01,
                f"{h:.3f}", ha="center", va="bottom", fontsize=8)
ax.set_xticks(x); ax.set_xticklabels(CLASS_NAMES)
ax.set_title("Per-Class Precision / Recall / F1", fontsize=13, fontweight="bold")
ax.set_ylim([0, 1.15]); ax.set_ylabel("Score"); ax.legend(); ax.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig("/kaggle/working/vit_step10_per_class_metrics.png", dpi=120, bbox_inches="tight")
plt.show()

print("\n" + "═" * 60)
print("  🌿 EARLY FUSION VIT-SMALL/16 — FINAL SUMMARY")
print("═" * 60)
print(f"  Fusion Type     : Early Fusion (RGB + Edge channel)")
print(f"  Input Shape     : [B, 4, 224, 224]")
print(f"  Backbone        : ViT-Small/16 (timm, pretrained ImageNet)")
print(f"  Fusion point    : patch_embed.proj (4-ch patch embedding conv)")
print(f"  Patch grid      : 14×14 = 196 tokens")
print(f"  Embed dim       : 384  |  Heads: 6  |  Depth: 12")
print(f"  Classes         : {', '.join(CLASS_NAMES)}")
print(f"  Test Accuracy   : {acc_pct:.2f}%")
print(f"  Weighted F1     : {weighted_f1:.4f}")
print(f"  Macro F1        : {macro_f1:.4f}")
print("─" * 60)
for cls, f1, p, r in zip(CLASS_NAMES, per_class_f1, per_prec, per_recall):
    print(f"    {cls:<18}  F1={f1:.4f}  Prec={p:.4f}  Rec={r:.4f}")
print("─" * 60)
print("  Saved files:")
for f in ["vit_step3_distribution.png", "vit_step4_fusion_channels.png",
           "vit_step8_training_curves.png", "vit_step9_test_results.csv",
           "vit_step10_confusion_matrix.png", "best_vit_early_fusion.pth"]:
    print(f"    ✓ /kaggle/working/{f}")
print("═" * 60)
print("  ✅ Step 10 complete — ViT-Small/16 pipeline finished!")
print("═" * 60)
# Out:
# ════════════════════════════════════════════════════════════
#   🌿 EARLY FUSION VIT-SMALL/16 — FINAL SUMMARY
# ════════════════════════════════════════════════════════════
#   Fusion Type     : Early Fusion (RGB + Edge channel)
#   Input Shape     : [B, 4, 224, 224]
#   Backbone        : ViT-Small/16 (timm, pretrained ImageNet)
#   Fusion point    : patch_embed.proj (4-ch patch embedding conv)
#   Patch grid      : 14×14 = 196 tokens
#   Embed dim       : 384  |  Heads: 6  |  Depth: 12
#   Classes         : Healthy_Leaf, Leaf_Rot, Leaf_Spot
#   Test Accuracy   : 94.46%
#   Weighted F1     : 0.9447
#   Macro F1        : 0.9413
# ────────────────────────────────────────────────────────────
#     Healthy_Leaf        F1=0.9595  Prec=0.9686  Rec=0.9506
#     Leaf_Rot            F1=0.9412  Prec=0.9091  Rec=0.9756
#     Leaf_Spot           F1=0.9231  Prec=0.9231  Rec=0.9231
# ────────────────────────────────────────────────────────────
#   Saved files:
#     ✓ /kaggle/working/vit_step3_distribution.png
#     ✓ /kaggle/working/vit_step4_fusion_channels.png
#     ✓ /kaggle/working/vit_step8_training_curves.png
#     ✓ /kaggle/working/vit_step9_test_results.csv
#     ✓ /kaggle/working/vit_step10_confusion_matrix.png
#     ✓ /kaggle/working/best_vit_early_fusion.pth
# ════════════════════════════════════════════════════════════
#   ✅ Step 10 complete — ViT-Small/16 pipeline finished!
# ════════════════════════════════════════════════════════════
